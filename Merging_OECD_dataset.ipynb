# %% [markdown]
# <a href="https://colab.research.google.com/github/westerlingter/analyzing-environmental-dimensions-of-quality-of-life_OECD-Data-Explorer-/blob/main/Merging_OECD_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

df_list = []
for i, filename in enumerate(uploaded.keys()):
  df = pd.read_csv(filename)
  df_list.append(df)
  globals()[f'df{i+1}'] = df
# Out:
#      <input type="file" id="files-6c602cb2-3d3e-448f-a516-752e91cfb80a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c602cb2-3d3e-448f-a516-752e91cfb80a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
index = [0,4,5,6]
df1 = df1.iloc[:,index]
df2 = df2.iloc[:,index]
df3 = df3.iloc[:,index]
df4 = df4.iloc[:,index]
df5 = df5.iloc[:,index]
df6 = df6.iloc[:,index]
df7 = df7.iloc[:,index]
df8 = df8.iloc[:,index]
df9 = df9.iloc[:,index]
df10 = df10.iloc[:,index]
df11 = df11.iloc[:,index]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Reference area  22 non-null     object
#  1   TIME_PERIOD     22 non-null     int64
#  2   O3_MOR          22 non-null     float64
#  3   UNIT_MEASURE    22 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 832.0+ bytes

# %%
##coba merge langsungan
from functools import reduce
data = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11]
by = ['Reference area','TIME_PERIOD','UNIT_MEASURE']
df_merge = reduce(lambda x,y: pd.merge(x,y, on=by, how  = 'outer'),data)

# %%
# perform a full outer join on the customer_id column
by = ['TIME_PERIOD','Reference area']
merge1 = pd.merge(df1, df2, on=by, how='outer')
merge2 = pd.merge(df3,df4, on=by, how='outer')
merge3 = pd.merge(df5, df6, on=by, how='outer')
merge4 = pd.merge(df7, df8, on=by, how='outer')
merge5 = pd.merge(df9, df10, on=by, how='outer')
merge6 = pd.merge(merge5, df11, on=by,how ='outer')

hasil1 = pd.merge(merge1, merge2, on=by, how='outer')
hasil2 = pd.merge(merge3, merge4, on=by, how='outer')
hasil3 = pd.merge(merge5, merge6, on=by, how='outer')

result1 = pd.merge(hasil1, hasil2, on=by, how='outer')
Final_result = pd.merge(result1,hasil3, on=by, how='outer')

# %%
Final_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Reference area      22 non-null     object
#  1   TIME_PERIOD         22 non-null     int64
#  2   O3_MOR              22 non-null     float64
#  3   UNIT_MEASURE_x_x_x  22 non-null     object
#  4   O3_SC               22 non-null     float64
#  5   UNIT_MEASURE_y_x_x  22 non-null     object
#  6   PB_MOR              22 non-null     float64
#  7   UNIT_MEASURE_x_y_x  22 non-null     object
#  8   PB_SC               22 non-null     float64
#  9   UNIT_MEASURE_y_y_x  22 non-null     object
#  10  PM_MOR              22 non-null     float64
#  11  UNIT_MEASURE_x_x_y  22 non-null     object
#  12  PM_PWM              12 non-null     float64
#  13  UNIT_MEASURE_y_x_y  12 non-null     object
#  14  PM_SC               22 non-null     float64
# ...

# %%
Final_result.head(10)
# Out:
#   Reference area  TIME_PERIOD  O3_MOR UNIT_MEASURE_x_x_x  O3_SC  \
# 0      Indonesia         1998    5.79          DT_10P6HB   0.06
# 1      Indonesia         1999    4.00          DT_10P6HB   0.04
# 2      Indonesia         2000    3.29          DT_10P6HB   0.03
# 3      Indonesia         2001    3.07          DT_10P6HB   0.03
# 4      Indonesia         2002    2.65          DT_10P6HB   0.03
# 5      Indonesia         2003    3.80          DT_10P6HB   0.04
# 6      Indonesia         2004    4.11          DT_10P6HB   0.05
# 7      Indonesia         2005    7.70          DT_10P6HB   0.09
# 8      Indonesia         2006    8.95          DT_10P6HB   0.10
# 9      Indonesia         2007    9.34          DT_10P6HB   0.11
#
#   UNIT_MEASURE_y_x_x  PB_MOR UNIT_MEASURE_x_y_x  PB_SC UNIT_MEASURE_y_y_x  \
# 0            PT_B1GQ   84.73          DT_10P6HB   0.85            PT_B1GQ
# 1            PT_B1GQ   86.36          DT_10P6HB   0.87            PT_B1GQ
# ...

# %%
Final_result.to_csv('Merge_data.csv')
